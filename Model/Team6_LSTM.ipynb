# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.layers import LSTM, Dense, Activation
from keras.models import Sequential
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error
import tensorflow as tf
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 1.Tỉ lệ 8:2

# %% [markdown]
# ### a.Dữ liệu giá vàng

# %% [markdown]
# #### Đọc dữ liệu và chia tập dữ liệu

# %%
df_gold = pd.read_csv('/kaggle/input/metal-dataset/gold_price_2018_2024.csv')
df_gold
# Out:
#             Date  Value (USD per troy ounce)
# 0     2018-01-01                 1307.018690
# 1     2018-01-02                 1319.827953
# 2     2018-01-03                 1311.501862
# 3     2018-01-04                 1321.635371
# 4     2018-01-05                 1319.589185
# ...          ...                         ...
# 2339  2024-05-28                 2353.805161
# 2340  2024-05-29                 2357.459733
# 2341  2024-05-30                 2335.806797
# 2342  2024-05-31                 2346.815711
# 2343  2024-06-01                 2327.903344
#
# [2344 rows x 2 columns]

# %%
df_gold.columns = ['Date', 'Price']
df_gold['Date'] = pd.to_datetime(df_gold['Date'])
df_gold['Price'] = df_gold.Price.astype(float)

df1 = df_gold.reset_index()['Price']

df1
# Out:
# 0       1307.018690
# 1       1319.827953
# 2       1311.501862
# 3       1321.635371
# 4       1319.589185
#            ...
# 2339    2353.805161
# 2340    2357.459733
# 2341    2335.806797
# 2342    2346.815711
# 2343    2327.903344
# Name: Price, Length: 2344, dtype: float64

# %%
x_plot = df_gold.Date
y_plot = df1.values
x_test_position = int(len(df_gold)*0.8)
x_value = df_gold.Date.iloc[x_test_position]
fig = plt.figure(figsize=(10, 5))

fig.tight_layout()

plt.plot(x_plot, y_plot)
plt.title('Biểu đồ đường thể hiện giá vàng')
plt.xlabel('Ngày', fontsize=17)
plt.ylabel('Giá vàng', fontsize=17)

plt.axvline(x_value, color='black', linestyle='-.')
plt.text(x_value, y_plot[x_test_position] - 100, '  Test', fontsize=12)

plt.show()
plt.close()

# %%
# Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
train_size = int(0.8 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

print('Train data size:', train_data.shape)
print('Test data size:', test_data.shape)
# Out:
# Train data size: (1875, 1)
# Test data size: (469, 1)

# %%
# Biến đổi mảng giá trị thành một bộ dữ liệu dạng ma trận
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return np.array(dataX), np.array(dataY)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# Reshape lại dữ liệu vì đây là yêu cầu cần thiết đối với đầu vào của LSTM
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

print('Train data size shape:', X_train.shape)
print('Test data size shape:', X_test.shape)
# Out:
# Train data size shape: (1774, 100, 1)
# Test data size shape: (368, 100, 1)

# %% [markdown]
# #### Tạo mô hình và train

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100, 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 138ms/step - loss: 0.0699 - val_loss: 0.0028
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 8.8720e-04 - val_loss: 0.0021
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 8.2221e-04 - val_loss: 0.0033
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 7.7691e-04 - val_loss: 0.0024
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 8.0725e-04 - val_loss: 0.0035
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 7.4785e-04 - val_loss: 0.0025
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 7.1264e-04 - val_loss: 0.0030
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 7.1838e-04 - val_loss: 0.0024
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 6.7703e-04 - val_loss: 0.0025
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 6.2479e-04 - val_loss: 0.0030
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - loss: 6.6904e-04 - val_loss: 0.0024
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 6.5645e-04 - val_loss: 0.0021
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 6.3559e-04 - val_loss: 0.0029
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 6.1076e-04 - val_loss: 0.0022
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - loss: 6.3854e-04 - val_loss: 0.0026
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 5.9893e-04 - val_loss: 0.0027
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 5.3215e-04 - val_loss: 0.0017
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 6.3418e-04 - val_loss: 0.0042
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 5.3558e-04 - val_loss: 0.0022
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 4.8847e-04 - val_loss: 0.0017
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 4.7712e-04 - val_loss: 0.0027
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 6.3524e-04 - val_loss: 0.0027
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 4.7630e-04 - val_loss: 0.0012
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - loss: 4.7812e-04 - val_loss: 8.4229e-04
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 6.1779e-04 - val_loss: 0.0015
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 4.8325e-04 - val_loss: 0.0013
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 4.3141e-04 - val_loss: 0.0016
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 4.3332e-04 - val_loss: 8.5326e-04
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 4.0842e-04 - val_loss: 0.0020
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 4.4706e-04 - val_loss: 0.0021
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 4.5987e-04 - val_loss: 0.0016
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 4.2392e-04 - val_loss: 5.9849e-04
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 3.6467e-04 - val_loss: 0.0013
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 3.7226e-04 - val_loss: 8.8985e-04
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 3.9663e-04 - val_loss: 5.5858e-04
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 4.2329e-04 - val_loss: 7.9331e-04
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 3.9207e-04 - val_loss: 0.0019
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 3.7271e-04 - val_loss: 5.9897e-04
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 3.6850e-04 - val_loss: 8.3818e-04
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 2.9189e-04 - val_loss: 6.3999e-04
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 3.4093e-04 - val_loss: 5.7943e-04
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 3.6978e-04 - val_loss: 0.0015
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 3.2662e-04 - val_loss: 6.3522e-04
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - loss: 2.7892e-04 - val_loss: 4.3286e-04
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 2.9421e-04 - val_loss: 0.0014
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 3.0842e-04 - val_loss: 0.0011
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 2.7358e-04 - val_loss: 3.8436e-04
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 2.7757e-04 - val_loss: 3.4555e-04
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 2.8490e-04 - val_loss: 5.2187e-04
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 2.4916e-04 - val_loss: 3.9049e-04
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 2.8001e-04 - val_loss: 4.8329e-04
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 2.1220e-04 - val_loss: 6.4973e-04
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 2.3303e-04 - val_loss: 4.3699e-04
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 1.8487e-04 - val_loss: 3.4042e-04
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 1.9838e-04 - val_loss: 3.1539e-04
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 1.9493e-04 - val_loss: 6.8958e-04
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 1.9621e-04 - val_loss: 0.0012
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - loss: 2.2520e-04 - val_loss: 4.0863e-04
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 1.6789e-04 - val_loss: 3.3497e-04
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 2.0631e-04 - val_loss: 3.4188e-04
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 1.6878e-04 - val_loss: 2.1791e-04
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 1.7480e-04 - val_loss: 4.4321e-04
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 1.6453e-04 - val_loss: 3.1852e-04
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 2.3347e-04 - val_loss: 2.4556e-04
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 1.8300e-04 - val_loss: 2.2150e-04
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 1.6343e-04 - val_loss: 2.1557e-04
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 1.8508e-04 - val_loss: 4.5939e-04
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 1.4309e-04 - val_loss: 2.2734e-04
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 1.9218e-04 - val_loss: 2.0289e-04
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 1.4536e-04 - val_loss: 4.4500e-04
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 2.3243e-04 - val_loss: 3.1012e-04
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 1.9605e-04 - val_loss: 2.2677e-04
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 1.6131e-04 - val_loss: 1.9261e-04
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 1.5174e-04 - val_loss: 2.1103e-04
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 1.7723e-04 - val_loss: 8.2876e-04
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 1.4907e-04 - val_loss: 2.5025e-04
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 1.3334e-04 - val_loss: 1.9455e-04
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 1.4573e-04 - val_loss: 1.8920e-04
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 1.6214e-04 - val_loss: 2.0169e-04
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 1.3982e-04 - val_loss: 4.5210e-04
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 1.4739e-04 - val_loss: 6.6366e-04
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 1.6817e-04 - val_loss: 3.4832e-04
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 1.5141e-04 - val_loss: 1.9048e-04
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 1.6951e-04 - val_loss: 5.0225e-04
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 1.6548e-04 - val_loss: 2.5232e-04
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 1.5116e-04 - val_loss: 4.9695e-04
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 1.5490e-04 - val_loss: 5.9213e-04
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 1.4895e-04 - val_loss: 2.0975e-04
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 1.4667e-04 - val_loss: 5.5806e-04
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 1.4471e-04 - val_loss: 1.9508e-04
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 1.3507e-04 - val_loss: 2.4895e-04
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 1.4553e-04 - val_loss: 3.1194e-04
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 1.3772e-04 - val_loss: 2.9649e-04
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 1.0857e-04 - val_loss: 2.1465e-04
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 1.3788e-04 - val_loss: 2.1166e-04
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 1.4399e-04 - val_loss: 1.8142e-04
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 1.4601e-04 - val_loss: 2.6304e-04
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 1.3730e-04 - val_loss: 2.5272e-04
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - loss: 1.2583e-04 - val_loss: 5.7141e-04

# %% [markdown]
# #### Dự báo và trực quan hoá

# %%
y_pred = model.predict(X_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step

# %%
# Chuẩn hóa dữ liệu y_pred, y_test
y_pred = scaler.inverse_transform(y_pred)
ytest = scaler.inverse_transform(ytest.reshape(-1, 1))

# %%
# Đánh giá độ chính xác thuật toán bằng RMSE
test_rmse = np.sqrt(np.mean((y_pred - ytest)**2))
test_mape = np.mean(np.abs((ytest - y_pred) / ytest)) * 100
test_mae = np.mean(np.abs(ytest - y_pred))


print('Testing RMSE:', test_rmse)
print('Testing MAPE:', test_mape)
print('Testing MAE:', test_mae)
# Out:
# Testing RMSE: 30.010297534891404
# Testing MAPE: 1.162725943023457
# Testing MAE: 24.49587420665143

# %%
# 13. Dự báo 90 ngày tiếp theo
x_input=test_data[:100].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()


lst_output=[]
n_steps=100
i=0

while(i<90):

    if(len(temp_input)>100):
        x_input=np.array(temp_input[1:])
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i=i+1

# %%
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data), color='green')
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index,scaler.inverse_transform(test_data), color='red')

test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index,(y_pred), color='blue')

predict_data_index_30 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
plt.plot(predict_data_index_30,scaler.inverse_transform(lst_output[0:30]), color='darkred')
predict_data_index_60 = pd.RangeIndex(start=len(df1)+29, stop=len(df1)+59, step=1)
plt.plot(predict_data_index_60,scaler.inverse_transform(lst_output[30:60]), color='orange')
predict_data_index_90 = pd.RangeIndex(start=len(df1)+59, stop=len(df1)+89, step=1)
plt.plot(predict_data_index_90,scaler.inverse_transform(lst_output[60:90]), color='purple')

plt.legend(['Dữ liệu huấn luyện','Dữ liệu thực tế','Dữ liệu dự đoán','Dự đoán 30 ngày', 'Dự đoán 60 ngày', 'Dự đoán 90 ngày'])
plt.title('Dự đoán giá vàng tỉ lệ 8:2 (LSTM)')
plt.ylabel('Giá vàng')
plt.show()

# %% [markdown]
# ### b.Dữ liệu giá bạc

# %% [markdown]
# #### Đọc dữ liệu và chia tập dữ liệu

# %%
df_silver = pd.read_csv('/kaggle/input/metal-dataset/silver_price_2018_2024.csv')
df_silver
# Out:
#             Date  Value (USD per troy ounce)
# 0     2018-01-01                   16.993771
# 1     2018-01-02                   17.196475
# 2     2018-01-03                   17.112426
# 3     2018-01-04                   17.200338
# 4     2018-01-05                   17.220985
# ...          ...                         ...
# 2339  2024-05-28                   31.790544
# 2340  2024-05-29                   31.992130
# 2341  2024-05-30                   31.825860
# 2342  2024-05-31                   31.137894
# 2343  2024-06-01                   30.408189
#
# [2344 rows x 2 columns]

# %%
df_silver.columns = ['Date', 'Price']
df_silver['Date'] = pd.to_datetime(df_silver['Date'])
df_silver['Price'] = df_silver.Price.astype(float)

df1 = df_silver.reset_index()['Price']

df1
# Out:
# 0       16.993771
# 1       17.196475
# 2       17.112426
# 3       17.200338
# 4       17.220985
#           ...
# 2339    31.790544
# 2340    31.992130
# 2341    31.825860
# 2342    31.137894
# 2343    30.408189
# Name: Price, Length: 2344, dtype: float64

# %%
x_plot = df_silver.Date
y_plot = df1.values
x_test_position = int(len(df_silver)*0.8)
x_value = df_silver.Date.iloc[x_test_position]
fig = plt.figure(figsize=(10, 5))

fig.tight_layout()

plt.plot(x_plot, y_plot)
plt.title('Biểu đồ đường thể hiện giá bạc')
plt.xlabel('Ngày', fontsize=17)
plt.ylabel('Giá bạc', fontsize=17)

plt.axvline(x_value, color='black', linestyle='-.')
plt.text(x_value, y_plot[x_test_position] - 10, '  Test', fontsize=12)

plt.show()
plt.close()

# %%
# Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
train_size = int(0.8 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

print('Train data size:', train_data.shape)
print('Test data size:', test_data.shape)
# Out:
# Train data size: (1875, 1)
# Test data size: (469, 1)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# Reshape lại dữ liệu vì đây là yêu cầu cần thiết đối với đầu vào của LSTM
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

print('Train data size shape:', X_train.shape)
print('Test data size shape:', X_test.shape)
# Out:
# Train data size shape: (1774, 100, 1)
# Test data size shape: (368, 100, 1)

# %% [markdown]
# #### Tạo mô hình và train

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100, 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 139ms/step - loss: 0.0517 - val_loss: 0.0096
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0040 - val_loss: 0.0045
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0022 - val_loss: 0.0040
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0012 - val_loss: 0.0027
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - loss: 0.0014 - val_loss: 0.0031
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 9.6704e-04 - val_loss: 0.0016
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 9.2442e-04 - val_loss: 0.0012
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 9.6368e-04 - val_loss: 0.0012
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - loss: 9.6101e-04 - val_loss: 0.0013
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 8.2739e-04 - val_loss: 0.0011
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 9.0742e-04 - val_loss: 9.9350e-04
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 8.6313e-04 - val_loss: 0.0010
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 9.0204e-04 - val_loss: 9.1778e-04
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 8.1684e-04 - val_loss: 8.9707e-04
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - loss: 8.1975e-04 - val_loss: 9.2573e-04
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 7.5915e-04 - val_loss: 8.6234e-04
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 8.7408e-04 - val_loss: 8.7960e-04
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 7.4502e-04 - val_loss: 8.2119e-04
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 8.2046e-04 - val_loss: 0.0011
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 8.4822e-04 - val_loss: 8.1218e-04
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 7.8560e-04 - val_loss: 7.5173e-04
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 7.3537e-04 - val_loss: 8.2774e-04
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 6.1629e-04 - val_loss: 8.0351e-04
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 6.7221e-04 - val_loss: 0.0012
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 7.2162e-04 - val_loss: 7.0524e-04
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 6.3066e-04 - val_loss: 6.8155e-04
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 5.7720e-04 - val_loss: 8.2689e-04
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 5.6049e-04 - val_loss: 6.9464e-04
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 6.3958e-04 - val_loss: 6.8938e-04
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 5.0761e-04 - val_loss: 6.4814e-04
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 5.6899e-04 - val_loss: 5.7131e-04
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 5.2594e-04 - val_loss: 5.6776e-04
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 6.3508e-04 - val_loss: 6.0681e-04
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 4.6129e-04 - val_loss: 7.2438e-04
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - loss: 4.7677e-04 - val_loss: 0.0020
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 7.6249e-04 - val_loss: 5.5225e-04
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - loss: 6.3748e-04 - val_loss: 6.2615e-04
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 5.5821e-04 - val_loss: 5.3304e-04
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 4.5812e-04 - val_loss: 6.7420e-04
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 5.3113e-04 - val_loss: 4.6595e-04
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 4.8229e-04 - val_loss: 4.6669e-04
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 4.0967e-04 - val_loss: 4.7137e-04
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - loss: 4.4077e-04 - val_loss: 4.8505e-04
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 3.8830e-04 - val_loss: 4.7825e-04
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 3.9230e-04 - val_loss: 4.9410e-04
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 3.5778e-04 - val_loss: 4.3611e-04
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 4.9070e-04 - val_loss: 4.2166e-04
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 5.2643e-04 - val_loss: 0.0011
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 6.4036e-04 - val_loss: 4.2713e-04
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - loss: 5.2748e-04 - val_loss: 4.2085e-04
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 3.7466e-04 - val_loss: 5.2266e-04
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 3.4738e-04 - val_loss: 5.8795e-04
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 4.5796e-04 - val_loss: 4.0684e-04
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - loss: 3.1477e-04 - val_loss: 4.0568e-04
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 3.2290e-04 - val_loss: 4.1062e-04
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 3.6457e-04 - val_loss: 4.1477e-04
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - loss: 3.9765e-04 - val_loss: 5.7361e-04
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 3.5159e-04 - val_loss: 3.9773e-04
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 4.1825e-04 - val_loss: 3.7835e-04
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 3.6519e-04 - val_loss: 4.0477e-04
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 3.1436e-04 - val_loss: 6.0159e-04
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 3.5793e-04 - val_loss: 4.0431e-04
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 2.7800e-04 - val_loss: 4.2624e-04
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 4.4995e-04 - val_loss: 8.1137e-04
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 5.2188e-04 - val_loss: 3.8799e-04
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - loss: 3.8834e-04 - val_loss: 4.9466e-04
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 3.5602e-04 - val_loss: 4.9959e-04
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 3.5165e-04 - val_loss: 4.0307e-04
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 3.1449e-04 - val_loss: 3.9846e-04
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 3.6635e-04 - val_loss: 4.9748e-04
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 3.8896e-04 - val_loss: 6.4355e-04
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 3.5629e-04 - val_loss: 3.8696e-04
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 3.0846e-04 - val_loss: 3.7548e-04
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 3.7464e-04 - val_loss: 3.8758e-04
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step - loss: 3.2510e-04 - val_loss: 3.9921e-04
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - loss: 3.3629e-04 - val_loss: 5.6419e-04
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 3.5348e-04 - val_loss: 5.5099e-04
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 3.9746e-04 - val_loss: 4.1326e-04
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 3.1298e-04 - val_loss: 3.9847e-04
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 3.8240e-04 - val_loss: 5.0775e-04
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 3.4853e-04 - val_loss: 4.5426e-04

# %% [markdown]
# #### Dự báo và trực quan hoá

# %%
y_pred = model.predict(X_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step

# %%
# Chuẩn hóa dữ liệu y_pred, y_test
y_pred = scaler.inverse_transform(y_pred)
ytest = scaler.inverse_transform(ytest.reshape(-1, 1))

# %%
# Đánh giá độ chính xác thuật toán bằng RMSE
test_rmse = np.sqrt(np.mean((y_pred - ytest)**2))
test_mape = np.mean(np.abs((ytest - y_pred) / ytest)) * 100
test_mae = np.mean(np.abs(ytest - y_pred))


print('Testing RMSE:', test_rmse)
print('Testing MAPE:', test_mape)
print('Testing MAE:', test_mae)
# Out:
# Testing RMSE: 0.4273366208593363
# Testing MAPE: 1.3595383608254163
# Testing MAE: 0.33001004982870147

# %%
# 13. Dự báo 90 ngày tiếp theo
x_input=test_data[:100].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()


lst_output=[]
n_steps=100
i=0

while(i<90):

    if(len(temp_input)>100):
        x_input=np.array(temp_input[1:])
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i=i+1

# %%
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data), color='green')
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index,scaler.inverse_transform(test_data), color='red')

test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index,(y_pred), color='blue')

predict_data_index_30 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
plt.plot(predict_data_index_30,scaler.inverse_transform(lst_output[0:30]), color='darkred')
predict_data_index_60 = pd.RangeIndex(start=len(df1)+29, stop=len(df1)+59, step=1)
plt.plot(predict_data_index_60,scaler.inverse_transform(lst_output[30:60]), color='orange')
predict_data_index_90 = pd.RangeIndex(start=len(df1)+59, stop=len(df1)+89, step=1)
plt.plot(predict_data_index_90,scaler.inverse_transform(lst_output[60:90]), color='purple')

plt.legend(['Dữ liệu huấn luyện','Dữ liệu thực tế','Dữ liệu dự đoán','Dự đoán 30 ngày', 'Dự đoán 60 ngày', 'Dự đoán 90 ngày'])
plt.title('Dự đoán giá bạc tỉ lệ 8:2(LSTM)')
plt.ylabel('Giá bạc')
plt.show()

# %% [markdown]
# ### c.Dữ liệu giá bạch kim

# %% [markdown]
# #### Đọc dữ liệu và chia tập dữ liệu

# %%
df_platium = pd.read_csv('/kaggle/input/metal-dataset/platium_price_2018_2024.csv')
df_platium
# Out:
#             Date  Value (USD per troy ounce)
# 0     2018-01-01                  930.030587
# 1     2018-01-02                  944.375754
# 2     2018-01-03                  954.910273
# 3     2018-01-04                  960.864535
# 4     2018-01-05                  969.196081
# ...          ...                         ...
# 2339  2024-05-28                 1062.333141
# 2340  2024-05-29                 1063.887962
# 2341  2024-05-30                 1036.777827
# 2342  2024-05-31                 1027.966127
# 2343  2024-06-01                 1009.071350
#
# [2344 rows x 2 columns]

# %%
df_platium.columns = ['Date', 'Price']
df_platium['Date'] = pd.to_datetime(df_platium['Date'])
df_platium['Price'] = df_platium.Price.astype(float)

df1 = df_platium.reset_index()['Price']

df1
# Out:
# 0        930.030587
# 1        944.375754
# 2        954.910273
# 3        960.864535
# 4        969.196081
#            ...
# 2339    1062.333141
# 2340    1063.887962
# 2341    1036.777827
# 2342    1027.966127
# 2343    1009.071350
# Name: Price, Length: 2344, dtype: float64

# %%
x_plot = df_platium.Date
y_plot = df1.values
x_test_position = int(len(df_platium)*0.8)
x_value = df_platium.Date.iloc[x_test_position]
fig = plt.figure(figsize=(10, 5))

fig.tight_layout()

plt.plot(x_plot, y_plot)
plt.title('Biểu đồ đường thể hiện giá bạch kim')
plt.xlabel('Ngày', fontsize=17)
plt.ylabel('Giá bạch kim', fontsize=17)

plt.axvline(x_value, color='black', linestyle='-.')
plt.text(x_value, y_plot[x_test_position] - 10, '  Test', fontsize=12)

plt.show()
plt.close()

# %%
# Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
train_size = int(0.8 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

print('Train data size:', train_data.shape)
print('Test data size:', test_data.shape)
# Out:
# Train data size: (1875, 1)
# Test data size: (469, 1)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# Reshape lại dữ liệu vì đây là yêu cầu cần thiết đối với đầu vào của LSTM
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

print('Train data size shape:', X_train.shape)
print('Test data size shape:', X_test.shape)
# Out:
# Train data size shape: (1774, 100, 1)
# Test data size shape: (368, 100, 1)

# %% [markdown]
# #### Tạo mô hình và train

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100, 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 140ms/step - loss: 0.1226 - val_loss: 0.0075
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0070 - val_loss: 0.0021
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0027 - val_loss: 0.0021
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0026 - val_loss: 0.0021
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0026 - val_loss: 0.0029
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0013 - val_loss: 9.5772e-04
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0013 - val_loss: 9.3779e-04
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 0.0012 - val_loss: 9.5835e-04
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - loss: 0.0012 - val_loss: 8.1712e-04
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 0.0011 - val_loss: 7.5656e-04
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - loss: 0.0011 - val_loss: 8.4119e-04
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - loss: 9.3740e-04 - val_loss: 7.0748e-04
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 9.3931e-04 - val_loss: 7.1514e-04
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0010 - val_loss: 7.1597e-04
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 8.1984e-04 - val_loss: 6.7083e-04
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 8.4316e-04 - val_loss: 6.6416e-04
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 7.9438e-04 - val_loss: 8.3848e-04
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 7.9467e-04 - val_loss: 7.9628e-04
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 8.4510e-04 - val_loss: 6.6616e-04
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 7.9436e-04 - val_loss: 6.0424e-04
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 6.1771e-04 - val_loss: 6.0894e-04
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 6.6492e-04 - val_loss: 5.7764e-04
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 7.4859e-04 - val_loss: 5.6839e-04
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - loss: 6.3417e-04 - val_loss: 9.2116e-04
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step - loss: 7.3135e-04 - val_loss: 6.3406e-04
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 6.9579e-04 - val_loss: 9.7219e-04
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 8.4982e-04 - val_loss: 6.7194e-04
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 6.4162e-04 - val_loss: 6.0519e-04
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 6.5631e-04 - val_loss: 5.8945e-04
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 6.4812e-04 - val_loss: 5.7746e-04
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 6.3027e-04 - val_loss: 5.5660e-04
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 6.2277e-04 - val_loss: 5.0271e-04
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - loss: 5.6005e-04 - val_loss: 6.6896e-04
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 5.6467e-04 - val_loss: 5.2795e-04
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 5.4850e-04 - val_loss: 4.7141e-04
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 5.1981e-04 - val_loss: 7.3841e-04
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 5.6948e-04 - val_loss: 4.5677e-04
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 5.0415e-04 - val_loss: 4.7831e-04
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - loss: 4.5555e-04 - val_loss: 4.4052e-04
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - loss: 4.9507e-04 - val_loss: 4.4722e-04
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 5.5401e-04 - val_loss: 9.6561e-04
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 6.4562e-04 - val_loss: 4.5374e-04
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 4.6827e-04 - val_loss: 5.3676e-04
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 4.9101e-04 - val_loss: 4.5949e-04
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 4.7822e-04 - val_loss: 6.2180e-04
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 6.2135e-04 - val_loss: 5.2311e-04
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 4.9953e-04 - val_loss: 4.2682e-04
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 4.6807e-04 - val_loss: 4.4948e-04
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 4.8671e-04 - val_loss: 5.7243e-04
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 5.8136e-04 - val_loss: 5.7471e-04
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 4.8377e-04 - val_loss: 4.1242e-04
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - loss: 5.0042e-04 - val_loss: 4.3298e-04
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 5.4843e-04 - val_loss: 5.6036e-04
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 5.0554e-04 - val_loss: 4.2045e-04
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 4.2911e-04 - val_loss: 4.0441e-04
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 4.4306e-04 - val_loss: 4.6175e-04
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 4.9893e-04 - val_loss: 5.9336e-04
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 5.2190e-04 - val_loss: 4.6505e-04
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 5.0976e-04 - val_loss: 5.6837e-04
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 4.9664e-04 - val_loss: 5.0186e-04
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 5.1486e-04 - val_loss: 4.1067e-04
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 4.6072e-04 - val_loss: 5.9313e-04
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - loss: 5.1557e-04 - val_loss: 4.1183e-04
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - loss: 5.1942e-04 - val_loss: 6.2375e-04
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 5.5410e-04 - val_loss: 4.3406e-04
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - loss: 4.2268e-04 - val_loss: 4.4961e-04
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 5.3876e-04 - val_loss: 4.2313e-04
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 5.1379e-04 - val_loss: 4.0705e-04
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 4.5445e-04 - val_loss: 4.1873e-04
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 4.7769e-04 - val_loss: 4.4090e-04
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 4.6471e-04 - val_loss: 4.3449e-04
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 4.9832e-04 - val_loss: 4.3236e-04
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 4.8445e-04 - val_loss: 4.1872e-04
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 4.3787e-04 - val_loss: 4.0721e-04
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - loss: 4.4988e-04 - val_loss: 4.9500e-04

# %% [markdown]
# #### Dự báo và trực quan hoá

# %%
y_pred = model.predict(X_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step

# %%
# Chuẩn hóa dữ liệu y_pred, y_test
y_pred = scaler.inverse_transform(y_pred)
ytest = scaler.inverse_transform(ytest.reshape(-1, 1))

# %%
# Đánh giá độ chính xác thuật toán bằng RMSE
test_rmse = np.sqrt(np.mean((y_pred - ytest)**2))
test_mape = np.mean(np.abs((ytest - y_pred) / ytest)) * 100
test_mae = np.mean(np.abs(ytest - y_pred))


print('Testing RMSE:', test_rmse)
print('Testing MAPE:', test_mape)
print('Testing MAE:', test_mae)
# Out:
# Testing RMSE: 15.912700034262167
# Testing MAPE: 1.2640512466400644
# Testing MAE: 11.92978923739806

# %%
# 13. Dự báo 90 ngày tiếp theo
x_input=test_data[:100].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()


lst_output=[]
n_steps=100
i=0

while(i<90):

    if(len(temp_input)>100):
        x_input=np.array(temp_input[1:])
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i=i+1

# %%
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data), color='green')
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index,scaler.inverse_transform(test_data), color='red')

test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index,(y_pred), color='blue')

predict_data_index_30 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
plt.plot(predict_data_index_30,scaler.inverse_transform(lst_output[0:30]), color='darkred')
predict_data_index_60 = pd.RangeIndex(start=len(df1)+29, stop=len(df1)+59, step=1)
plt.plot(predict_data_index_60,scaler.inverse_transform(lst_output[30:60]), color='orange')
predict_data_index_90 = pd.RangeIndex(start=len(df1)+59, stop=len(df1)+89, step=1)
plt.plot(predict_data_index_90,scaler.inverse_transform(lst_output[60:90]), color='purple')

plt.legend(['Dữ liệu huấn luyện','Dữ liệu thực tế','Dữ liệu dự đoán','Dự đoán 30 ngày', 'Dự đoán 60 ngày', 'Dự đoán 90 ngày'])
plt.title('Dự đoán giá bạch kim tỉ lệ 8:2(LSTM)')
plt.ylabel('Giá bạch kim')
plt.show()

# %% [markdown]
# ## 1.Tỉ lệ 9:1

# %% [markdown]
# ### a.Dữ liệu giá vàng

# %% [markdown]
# #### Đọc dữ liệu và chia tập dữ liệu

# %%
df_gold.columns = ['Date', 'Price']
df_gold['Date'] = pd.to_datetime(df_gold['Date'])
df_gold['Price'] = df_gold.Price.astype(float)

df1 = df_gold.reset_index()['Price']

df1
# Out:
# 0       1307.018690
# 1       1319.827953
# 2       1311.501862
# 3       1321.635371
# 4       1319.589185
#            ...
# 2339    2353.805161
# 2340    2357.459733
# 2341    2335.806797
# 2342    2346.815711
# 2343    2327.903344
# Name: Price, Length: 2344, dtype: float64

# %%
x_plot = df_gold.Date
y_plot = df1.values
x_test_position = int(len(df_gold)*0.9)
x_value = df_gold.Date.iloc[x_test_position]
fig = plt.figure(figsize=(10, 5))

fig.tight_layout()

plt.plot(x_plot, y_plot)
plt.title('Biểu đồ đường thể hiện giá vàng')
plt.xlabel('Ngày', fontsize=17)
plt.ylabel('Giá vàng', fontsize=17)

plt.axvline(x_value, color='black', linestyle='-.')
plt.text(x_value, y_plot[x_test_position] - 100, '  Test', fontsize=12)

plt.show()
plt.close()

# %%
# Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
train_size = int(0.9 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

print('Train data size:', train_data.shape)
print('Test data size:', test_data.shape)
# Out:
# Train data size: (2109, 1)
# Test data size: (235, 1)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# Reshape lại dữ liệu vì đây là yêu cầu cần thiết đối với đầu vào của LSTM
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

print('Train data size shape:', X_train.shape)
print('Test data size shape:', X_test.shape)
# Out:
# Train data size shape: (2008, 100, 1)
# Test data size shape: (134, 100, 1)

# %% [markdown]
# #### Tạo mô hình và train

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100, 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - loss: 0.0327 - val_loss: 0.0241
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 0.0013 - val_loss: 0.0075
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - loss: 9.7077e-04 - val_loss: 0.0097
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - loss: 8.4952e-04 - val_loss: 0.0085
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - loss: 9.9101e-04 - val_loss: 0.0086
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 9.3803e-04 - val_loss: 0.0085
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 7.9018e-04 - val_loss: 0.0097
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 8.7875e-04 - val_loss: 0.0085
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 7.4936e-04 - val_loss: 0.0060
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 7.5075e-04 - val_loss: 0.0038
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 7.0378e-04 - val_loss: 0.0042
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 6.7210e-04 - val_loss: 0.0082
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 7.3677e-04 - val_loss: 0.0057
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 6.4961e-04 - val_loss: 0.0041
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 5.7928e-04 - val_loss: 0.0038
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 5.4733e-04 - val_loss: 0.0026
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 5.9524e-04 - val_loss: 0.0013
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 6.1990e-04 - val_loss: 0.0036
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 5.4687e-04 - val_loss: 0.0031
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 4.6462e-04 - val_loss: 0.0040
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 5.3833e-04 - val_loss: 0.0047
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 5.3144e-04 - val_loss: 0.0042
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - loss: 6.8147e-04 - val_loss: 0.0032
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 4.3794e-04 - val_loss: 0.0014
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 4.8118e-04 - val_loss: 8.9572e-04
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 4.5534e-04 - val_loss: 0.0030
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 4.2580e-04 - val_loss: 0.0010
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 4.2493e-04 - val_loss: 0.0012
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - loss: 4.7685e-04 - val_loss: 0.0011
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 4.7589e-04 - val_loss: 0.0025
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 4.3945e-04 - val_loss: 0.0014
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 4.3725e-04 - val_loss: 0.0013
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 4.0039e-04 - val_loss: 0.0017
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 4.1775e-04 - val_loss: 0.0018
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 4.0792e-04 - val_loss: 9.8198e-04
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - loss: 3.7379e-04 - val_loss: 9.4176e-04
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 4.4859e-04 - val_loss: 0.0017
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 4.2769e-04 - val_loss: 0.0017
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 3.4780e-04 - val_loss: 9.5349e-04
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 3.8499e-04 - val_loss: 9.3339e-04
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 3.4314e-04 - val_loss: 7.3337e-04
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 3.8446e-04 - val_loss: 9.8537e-04
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 3.7455e-04 - val_loss: 0.0017
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 3.4731e-04 - val_loss: 0.0011
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 3.1490e-04 - val_loss: 0.0012
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - loss: 3.1431e-04 - val_loss: 0.0017
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 3.0448e-04 - val_loss: 0.0018
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 3.1899e-04 - val_loss: 0.0013
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 3.3240e-04 - val_loss: 0.0015
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 2.9188e-04 - val_loss: 0.0044
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 4.4223e-04 - val_loss: 0.0014
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 3.0650e-04 - val_loss: 0.0012
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 2.6997e-04 - val_loss: 6.3214e-04
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - loss: 2.9627e-04 - val_loss: 9.3982e-04
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - loss: 2.9531e-04 - val_loss: 5.3873e-04
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - loss: 2.8258e-04 - val_loss: 4.2675e-04
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 2.4500e-04 - val_loss: 4.3642e-04
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 3.1575e-04 - val_loss: 7.5182e-04
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 2.4927e-04 - val_loss: 6.3022e-04
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 2.4044e-04 - val_loss: 4.5572e-04
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 2.6003e-04 - val_loss: 0.0015
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - loss: 2.6899e-04 - val_loss: 7.0174e-04
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 2.2685e-04 - val_loss: 9.8272e-04
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 2.2194e-04 - val_loss: 0.0019
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 2.1797e-04 - val_loss: 3.1415e-04
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 2.3848e-04 - val_loss: 3.6083e-04
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 2.1436e-04 - val_loss: 0.0028
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 3.1915e-04 - val_loss: 7.2710e-04
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 1.9724e-04 - val_loss: 0.0012
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 2.0446e-04 - val_loss: 2.8820e-04
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - loss: 2.0671e-04 - val_loss: 0.0035
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 3.4451e-04 - val_loss: 0.0011
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 1.8460e-04 - val_loss: 2.6136e-04
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 1.8922e-04 - val_loss: 5.6930e-04
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 1.9904e-04 - val_loss: 2.6110e-04
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 1.7170e-04 - val_loss: 7.9959e-04
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 2.2232e-04 - val_loss: 3.9171e-04
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 1.6981e-04 - val_loss: 2.9921e-04
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - loss: 2.4969e-04 - val_loss: 4.9948e-04
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - loss: 1.6412e-04 - val_loss: 2.6011e-04
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 1.5291e-04 - val_loss: 9.7003e-04
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - loss: 1.8219e-04 - val_loss: 8.1758e-04
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 1.5338e-04 - val_loss: 3.0210e-04
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 1.9877e-04 - val_loss: 2.3487e-04
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 1.8165e-04 - val_loss: 2.9177e-04
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 1.5683e-04 - val_loss: 2.5804e-04
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - loss: 1.7990e-04 - val_loss: 6.3124e-04
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 1.5180e-04 - val_loss: 2.8397e-04
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 1.9802e-04 - val_loss: 3.2051e-04
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 1.3025e-04 - val_loss: 5.3167e-04
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 1.3789e-04 - val_loss: 6.1652e-04
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - loss: 1.6690e-04 - val_loss: 2.5953e-04
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 1.5275e-04 - val_loss: 2.6785e-04
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 1.6117e-04 - val_loss: 4.0055e-04
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 1.4327e-04 - val_loss: 8.9103e-04
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 1.7219e-04 - val_loss: 2.3651e-04
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 1.2110e-04 - val_loss: 2.5744e-04
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 1.4141e-04 - val_loss: 2.7553e-04
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 1.4929e-04 - val_loss: 2.4504e-04
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 1.5577e-04 - val_loss: 3.2611e-04

# %% [markdown]
# #### Dự báo và trực quan hoá

# %%
y_pred = model.predict(X_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step

# %%
# Chuẩn hóa dữ liệu y_pred, y_test
y_pred = scaler.inverse_transform(y_pred)
ytest = scaler.inverse_transform(ytest.reshape(-1, 1))

# %%
# Đánh giá độ chính xác thuật toán bằng RMSE
test_rmse = np.sqrt(np.mean((y_pred - ytest)**2))
test_mape = np.mean(np.abs((ytest - y_pred) / ytest)) * 100
test_mae = np.mean(np.abs(ytest - y_pred))


print('Testing RMSE:', test_rmse)
print('Testing MAPE:', test_mape)
print('Testing MAE:', test_mae)
# Out:
# Testing RMSE: 22.671403686399998
# Testing MAPE: 0.8484636762802213
# Testing MAE: 18.538195813226295

# %%
# 13. Dự báo 90 ngày tiếp theo
x_input=test_data[:100].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()


lst_output=[]
n_steps=100
i=0

while(i<90):

    if(len(temp_input)>100):
        x_input=np.array(temp_input[1:])
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i=i+1

# %%
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data), color='green')
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index,scaler.inverse_transform(test_data), color='red')

test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index,(y_pred), color='blue')

predict_data_index_30 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
plt.plot(predict_data_index_30,scaler.inverse_transform(lst_output[0:30]), color='darkred')
predict_data_index_60 = pd.RangeIndex(start=len(df1)+29, stop=len(df1)+59, step=1)
plt.plot(predict_data_index_60,scaler.inverse_transform(lst_output[30:60]), color='orange')
predict_data_index_90 = pd.RangeIndex(start=len(df1)+59, stop=len(df1)+89, step=1)
plt.plot(predict_data_index_90,scaler.inverse_transform(lst_output[60:90]), color='purple')

plt.legend(['Dữ liệu huấn luyện','Dữ liệu thực tế','Dữ liệu dự đoán','Dự đoán 30 ngày', 'Dự đoán 60 ngày', 'Dự đoán 90 ngày'])
plt.title('Dự đoán giá vàng bằng tỉ lệ 9:1(LSTM)')
plt.ylabel('Giá vàng')
plt.show()

# %% [markdown]
# ### b.Dữ liệu giá bạc

# %% [markdown]
# #### Đọc dữ liệu và chia tập dữ liệu

# %%
df_silver.columns = ['Date', 'Price']
df_silver['Date'] = pd.to_datetime(df_silver['Date'])
df_silver['Price'] = df_silver.Price.astype(float)

df1 = df_silver.reset_index()['Price']

df1
# Out:
# 0       16.993771
# 1       17.196475
# 2       17.112426
# 3       17.200338
# 4       17.220985
#           ...
# 2339    31.790544
# 2340    31.992130
# 2341    31.825860
# 2342    31.137894
# 2343    30.408189
# Name: Price, Length: 2344, dtype: float64

# %%
x_plot = df_silver.Date
y_plot = df1.values
x_test_position = int(len(df_silver)*0.9)
x_value = df_silver.Date.iloc[x_test_position]
fig = plt.figure(figsize=(10, 5))

fig.tight_layout()

plt.plot(x_plot, y_plot)
plt.title('Biểu đồ đường thể hiện giá bạc')
plt.xlabel('Ngày', fontsize=17)
plt.ylabel('Giá bạc', fontsize=17)

plt.axvline(x_value, color='black', linestyle='-.')
plt.text(x_value, y_plot[x_test_position] - 10, '  Test', fontsize=12)

plt.show()
plt.close()

# %%
# Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
train_size = int(0.9 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

print('Train data size:', train_data.shape)
print('Test data size:', test_data.shape)
# Out:
# Train data size: (2109, 1)
# Test data size: (235, 1)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# Reshape lại dữ liệu vì đây là yêu cầu cần thiết đối với đầu vào của LSTM
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

print('Train data size shape:', X_train.shape)
print('Test data size shape:', X_test.shape)
# Out:
# Train data size shape: (2008, 100, 1)
# Test data size shape: (134, 100, 1)

# %% [markdown]
# #### Tạo mô hình và train

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100, 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - loss: 0.0608 - val_loss: 0.0166
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0030 - val_loss: 0.0058
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0023 - val_loss: 0.0045
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 0.0021 - val_loss: 0.0046
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0018 - val_loss: 0.0060
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 0.0020 - val_loss: 0.0063
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0017 - val_loss: 0.0075
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - loss: 0.0017 - val_loss: 0.0039
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 0.0014 - val_loss: 0.0029
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 9.9028e-04 - val_loss: 0.0015
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 9.6487e-04 - val_loss: 0.0016
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 9.1002e-04 - val_loss: 0.0012
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 8.6272e-04 - val_loss: 0.0021
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 8.1682e-04 - val_loss: 0.0014
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 8.0362e-04 - val_loss: 0.0014
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 7.5008e-04 - val_loss: 0.0012
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 7.2334e-04 - val_loss: 0.0015
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 6.1562e-04 - val_loss: 0.0026
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 8.0956e-04 - val_loss: 8.9636e-04
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 7.2035e-04 - val_loss: 9.2408e-04
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 6.5180e-04 - val_loss: 0.0011
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 6.0177e-04 - val_loss: 8.0076e-04
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 8.2968e-04 - val_loss: 0.0012
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 6.1344e-04 - val_loss: 8.7052e-04
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 5.3063e-04 - val_loss: 7.6228e-04
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 5.7062e-04 - val_loss: 7.0814e-04
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 4.9533e-04 - val_loss: 6.8545e-04
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 4.9475e-04 - val_loss: 6.4412e-04
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 5.8724e-04 - val_loss: 8.2176e-04
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - loss: 5.0368e-04 - val_loss: 7.2090e-04
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 4.2646e-04 - val_loss: 7.3132e-04
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 4.2766e-04 - val_loss: 0.0014
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 5.4393e-04 - val_loss: 0.0011
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 4.0719e-04 - val_loss: 5.9062e-04
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 5.1903e-04 - val_loss: 6.6869e-04
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 4.4309e-04 - val_loss: 0.0018
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 4.9247e-04 - val_loss: 5.3989e-04
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 3.9117e-04 - val_loss: 5.2770e-04
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 3.9285e-04 - val_loss: 0.0012
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - loss: 5.4858e-04 - val_loss: 5.2657e-04
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 3.6561e-04 - val_loss: 0.0010
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 4.8040e-04 - val_loss: 0.0012
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 7.3663e-04 - val_loss: 6.1426e-04
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 5.1262e-04 - val_loss: 5.6350e-04
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 3.5336e-04 - val_loss: 5.5813e-04
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 4.0991e-04 - val_loss: 7.1155e-04
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - loss: 3.7980e-04 - val_loss: 5.2493e-04
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 4.0096e-04 - val_loss: 5.3992e-04
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 3.5620e-04 - val_loss: 6.4478e-04
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 3.3958e-04 - val_loss: 5.3010e-04
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 4.1378e-04 - val_loss: 7.0574e-04
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 3.1410e-04 - val_loss: 6.5511e-04
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 3.3688e-04 - val_loss: 5.5664e-04
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - loss: 3.9222e-04 - val_loss: 6.8155e-04
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 3.0119e-04 - val_loss: 7.5586e-04
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 3.6866e-04 - val_loss: 7.9055e-04
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - loss: 3.8546e-04 - val_loss: 5.4027e-04
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 3.6871e-04 - val_loss: 0.0012
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 5.0999e-04 - val_loss: 5.2274e-04
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 3.1433e-04 - val_loss: 5.1766e-04
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 3.7235e-04 - val_loss: 5.5013e-04
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 3.5622e-04 - val_loss: 6.3715e-04
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 3.1659e-04 - val_loss: 5.2720e-04
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - loss: 3.3940e-04 - val_loss: 0.0011
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 4.4961e-04 - val_loss: 8.4326e-04
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 4.1987e-04 - val_loss: 5.6463e-04
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 2.8386e-04 - val_loss: 0.0010
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 3.0910e-04 - val_loss: 0.0011
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 2.9708e-04 - val_loss: 6.3071e-04
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 4.0310e-04 - val_loss: 0.0010
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - loss: 3.8385e-04 - val_loss: 9.0255e-04
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 3.7243e-04 - val_loss: 6.0886e-04
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 3.3505e-04 - val_loss: 7.8906e-04
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 3.0277e-04 - val_loss: 0.0013
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 4.0669e-04 - val_loss: 0.0020
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 4.9260e-04 - val_loss: 0.0015
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - loss: 3.7480e-04 - val_loss: 9.8099e-04
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 3.7903e-04 - val_loss: 6.5418e-04
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - loss: 3.1012e-04 - val_loss: 5.6450e-04
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 3.3417e-04 - val_loss: 6.6813e-04
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 4.5384e-04 - val_loss: 9.5941e-04
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 3.8147e-04 - val_loss: 0.0010
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 3.4710e-04 - val_loss: 5.9520e-04
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 3.1301e-04 - val_loss: 7.5692e-04
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 3.1988e-04 - val_loss: 5.9296e-04
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 3.1330e-04 - val_loss: 5.6542e-04
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - loss: 3.1059e-04 - val_loss: 5.9848e-04

# %% [markdown]
# #### Dự báo và trực quan hoá

# %%
y_pred = model.predict(X_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step

# %%
# Chuẩn hóa dữ liệu y_pred, y_test
y_pred = scaler.inverse_transform(y_pred)
ytest = scaler.inverse_transform(ytest.reshape(-1, 1))

# %%
# Đánh giá độ chính xác thuật toán bằng RMSE
test_rmse = np.sqrt(np.mean((y_pred - ytest)**2))
test_mape = np.mean(np.abs((ytest - y_pred) / ytest)) * 100
test_mae = np.mean(np.abs(ytest - y_pred))


print('Testing RMSE:', test_rmse)
print('Testing MAPE:', test_mape)
print('Testing MAE:', test_mae)
# Out:
# Testing RMSE: 0.4905013193774552
# Testing MAPE: 1.2183200100032714
# Testing MAE: 0.3257232205881621

# %%
# 13. Dự báo 90 ngày tiếp theo
x_input=test_data[:100].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()


lst_output=[]
n_steps=100
i=0

while(i<90):

    if(len(temp_input)>100):
        x_input=np.array(temp_input[1:])
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i=i+1

# %%
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data), color='green')
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index,scaler.inverse_transform(test_data), color='red')

test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index,(y_pred), color='blue')

predict_data_index_30 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
plt.plot(predict_data_index_30,scaler.inverse_transform(lst_output[0:30]), color='darkred')
predict_data_index_60 = pd.RangeIndex(start=len(df1)+29, stop=len(df1)+59, step=1)
plt.plot(predict_data_index_60,scaler.inverse_transform(lst_output[30:60]), color='orange')
predict_data_index_90 = pd.RangeIndex(start=len(df1)+59, stop=len(df1)+89, step=1)
plt.plot(predict_data_index_90,scaler.inverse_transform(lst_output[60:90]), color='purple')

plt.legend(['Dữ liệu huấn luyện','Dữ liệu thực tế','Dữ liệu dự đoán','Dự đoán 30 ngày', 'Dự đoán 60 ngày', 'Dự đoán 90 ngày'])
plt.title('Dự đoán giá bạc tỉ lệ 9:1(LSTM)')
plt.ylabel('Giá bạc')
plt.show()

# %% [markdown]
# ### c.Dữ liệu giá bạch kim

# %% [markdown]
# #### Đọc dữ liệu và chia tập dữ liệu

# %%
df_platium.columns = ['Date', 'Price']
df_platium['Date'] = pd.to_datetime(df_platium['Date'])
df_platium['Price'] = df_platium.Price.astype(float)

df1 = df_platium.reset_index()['Price']

df1
# Out:
# 0        930.030587
# 1        944.375754
# 2        954.910273
# 3        960.864535
# 4        969.196081
#            ...
# 2339    1062.333141
# 2340    1063.887962
# 2341    1036.777827
# 2342    1027.966127
# 2343    1009.071350
# Name: Price, Length: 2344, dtype: float64

# %%
x_plot = df_platium.Date
y_plot = df1.values
x_test_position = int(len(df_platium)*0.9)
x_value = df_platium.Date.iloc[x_test_position]
fig = plt.figure(figsize=(10, 5))

fig.tight_layout()

plt.plot(x_plot, y_plot)
plt.title('Biểu đồ đường thể hiện giá bạch kim')
plt.xlabel('Ngày', fontsize=17)
plt.ylabel('Giá bạch kim', fontsize=17)

plt.axvline(x_value, color='black', linestyle='-.')
plt.text(x_value, y_plot[x_test_position] - 10, '  Test', fontsize=12)

plt.show()
plt.close()

# %%
# Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
train_size = int(0.9 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

print('Train data size:', train_data.shape)
print('Test data size:', test_data.shape)
# Out:
# Train data size: (2109, 1)
# Test data size: (235, 1)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# Reshape lại dữ liệu vì đây là yêu cầu cần thiết đối với đầu vào của LSTM
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

print('Train data size shape:', X_train.shape)
print('Test data size shape:', X_test.shape)
# Out:
# Train data size shape: (2008, 100, 1)
# Test data size shape: (134, 100, 1)

# %% [markdown]
# #### Tạo mô hình và train

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100, 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - loss: 0.0863 - val_loss: 0.0029
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0049 - val_loss: 0.0020
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 0.0026 - val_loss: 0.0034
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0028 - val_loss: 0.0019
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 0.0015 - val_loss: 9.3127e-04
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - loss: 0.0012 - val_loss: 8.7477e-04
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0012 - val_loss: 8.6623e-04
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0012 - val_loss: 8.0991e-04
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 0.0011 - val_loss: 7.7346e-04
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0010 - val_loss: 7.7845e-04
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - loss: 9.8095e-04 - val_loss: 7.2032e-04
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 8.5037e-04 - val_loss: 7.6172e-04
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 8.9573e-04 - val_loss: 7.5140e-04
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - loss: 9.3230e-04 - val_loss: 0.0012
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 8.6776e-04 - val_loss: 6.5203e-04
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - loss: 8.9685e-04 - val_loss: 6.8289e-04
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 7.7002e-04 - val_loss: 8.4864e-04
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 7.7509e-04 - val_loss: 7.1337e-04
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - loss: 7.2251e-04 - val_loss: 6.8307e-04
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 6.7198e-04 - val_loss: 7.4406e-04
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 6.9475e-04 - val_loss: 6.2049e-04
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - loss: 6.6809e-04 - val_loss: 6.8784e-04
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 6.7420e-04 - val_loss: 0.0010
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 8.2257e-04 - val_loss: 6.9670e-04
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 6.4615e-04 - val_loss: 7.1789e-04
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 5.6743e-04 - val_loss: 8.5049e-04
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 6.2404e-04 - val_loss: 7.3870e-04
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 6.3687e-04 - val_loss: 6.1452e-04
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 5.1799e-04 - val_loss: 6.4402e-04
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 5.9175e-04 - val_loss: 6.9787e-04
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - loss: 4.6979e-04 - val_loss: 7.1232e-04
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 6.5107e-04 - val_loss: 5.6387e-04
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 6.1163e-04 - val_loss: 5.6023e-04
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - loss: 5.1821e-04 - val_loss: 6.7841e-04
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 5.4316e-04 - val_loss: 5.3359e-04
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 5.0297e-04 - val_loss: 6.4618e-04
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 6.4422e-04 - val_loss: 5.8495e-04
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - loss: 5.2520e-04 - val_loss: 6.2448e-04
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 5.7428e-04 - val_loss: 5.9569e-04
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 4.5900e-04 - val_loss: 5.6359e-04
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 5.3750e-04 - val_loss: 5.3056e-04
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 5.1321e-04 - val_loss: 8.5997e-04
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 5.8289e-04 - val_loss: 6.6859e-04
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 4.9860e-04 - val_loss: 5.5336e-04
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 4.7060e-04 - val_loss: 5.8571e-04
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 6.0059e-04 - val_loss: 6.1428e-04
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 4.5826e-04 - val_loss: 5.1156e-04
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 4.9481e-04 - val_loss: 5.4551e-04
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 6.0270e-04 - val_loss: 5.3306e-04
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 5.0879e-04 - val_loss: 5.4638e-04
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 4.9647e-04 - val_loss: 5.0784e-04
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 4.9005e-04 - val_loss: 5.0863e-04
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 4.4910e-04 - val_loss: 5.7455e-04
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - loss: 5.9334e-04 - val_loss: 5.0806e-04
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - loss: 4.6257e-04 - val_loss: 5.2634e-04
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 4.3846e-04 - val_loss: 5.1021e-04
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 4.5869e-04 - val_loss: 5.2903e-04
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 3.9779e-04 - val_loss: 6.7303e-04
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 4.4993e-04 - val_loss: 7.4333e-04
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 6.3120e-04 - val_loss: 7.2114e-04
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 5.5428e-04 - val_loss: 5.2767e-04
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 4.3371e-04 - val_loss: 5.1825e-04
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 4.5760e-04 - val_loss: 5.0734e-04
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 4.6981e-04 - val_loss: 5.7601e-04
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 4.8477e-04 - val_loss: 5.0676e-04
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 4.3019e-04 - val_loss: 5.4957e-04
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 4.3621e-04 - val_loss: 6.8652e-04
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 4.5799e-04 - val_loss: 5.1771e-04
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 5.2359e-04 - val_loss: 0.0010
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 5.9437e-04 - val_loss: 5.2140e-04
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 4.8489e-04 - val_loss: 5.9826e-04
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 5.0627e-04 - val_loss: 5.0683e-04
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 4.6756e-04 - val_loss: 5.2316e-04
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 4.5156e-04 - val_loss: 5.1940e-04
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 4.4530e-04 - val_loss: 5.1962e-04
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 4.8856e-04 - val_loss: 5.1703e-04
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 4.0911e-04 - val_loss: 5.1196e-04
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 4.4374e-04 - val_loss: 5.2683e-04
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - loss: 4.3789e-04 - val_loss: 5.2367e-04
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 4.4268e-04 - val_loss: 5.4533e-04
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - loss: 4.8888e-04 - val_loss: 5.0731e-04
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 4.9347e-04 - val_loss: 5.1071e-04
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 5.0797e-04 - val_loss: 5.6506e-04
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 4.5785e-04 - val_loss: 7.1205e-04
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - loss: 4.8522e-04 - val_loss: 5.1532e-04

# %% [markdown]
# #### Dự báo và trực quan hoá

# %%
y_pred = model.predict(X_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step

# %%
# Chuẩn hóa dữ liệu y_pred, y_test
y_pred = scaler.inverse_transform(y_pred)
ytest = scaler.inverse_transform(ytest.reshape(-1, 1))

# %%
# Đánh giá độ chính xác thuật toán bằng RMSE
test_rmse = np.sqrt(np.mean((y_pred - ytest)**2))
test_mape = np.mean(np.abs((ytest - y_pred) / ytest)) * 100
test_mae = np.mean(np.abs(ytest - y_pred))


print('Testing RMSE:', test_rmse)
print('Testing MAPE:', test_mape)
print('Testing MAE:', test_mae)
# Out:
# Testing RMSE: 16.23611558681873
# Testing MAPE: 1.242188092594062
# Testing MAE: 11.896444119374356

# %%
# 13. Dự báo 90 ngày tiếp theo
x_input=test_data[:100].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()


lst_output=[]
n_steps=100
i=0

while(i<90):

    if(len(temp_input)>100):
        x_input=np.array(temp_input[1:])
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i=i+1

# %%
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data), color='green')
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index,scaler.inverse_transform(test_data), color='red')

test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index,(y_pred), color='blue')

predict_data_index_30 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
plt.plot(predict_data_index_30,scaler.inverse_transform(lst_output[0:30]), color='darkred')
predict_data_index_60 = pd.RangeIndex(start=len(df1)+29, stop=len(df1)+59, step=1)
plt.plot(predict_data_index_60,scaler.inverse_transform(lst_output[30:60]), color='orange')
predict_data_index_90 = pd.RangeIndex(start=len(df1)+59, stop=len(df1)+89, step=1)
plt.plot(predict_data_index_90,scaler.inverse_transform(lst_output[60:90]), color='purple')

plt.legend(['Dữ liệu huấn luyện','Dữ liệu thực tế','Dữ liệu dự đoán','Dự đoán 30 ngày', 'Dự đoán 60 ngày', 'Dự đoán 90 ngày'])
plt.title('Dự đoán giá bạch kim tỉ lệ 9:1(LSTM)')
plt.ylabel('Giá bạch kim')
plt.show()

# %% [markdown]
# ## 1.Tỉ lệ 7:3

# %% [markdown]
# ### a.Dữ liệu giá vàng

# %% [markdown]
# #### Đọc dữ liệu và chia tập dữ liệu

# %%
df_gold.columns = ['Date', 'Price']
df_gold['Date'] = pd.to_datetime(df_gold['Date'])
df_gold['Price'] = df_gold.Price.astype(float)

df1 = df_gold.reset_index()['Price']

df1
# Out:
# 0       1307.018690
# 1       1319.827953
# 2       1311.501862
# 3       1321.635371
# 4       1319.589185
#            ...
# 2339    2353.805161
# 2340    2357.459733
# 2341    2335.806797
# 2342    2346.815711
# 2343    2327.903344
# Name: Price, Length: 2344, dtype: float64

# %%
x_plot = df_gold.Date
y_plot = df1.values
x_test_position = int(len(df_gold)*0.7)
x_value = df_gold.Date.iloc[x_test_position]
fig = plt.figure(figsize=(10, 5))

fig.tight_layout()

plt.plot(x_plot, y_plot)
plt.title('Biểu đồ đường thể hiện giá vàng')
plt.xlabel('Ngày', fontsize=17)
plt.ylabel('Giá vàng', fontsize=17)

plt.axvline(x_value, color='black', linestyle='-.')
plt.text(x_value, y_plot[x_test_position] - 100, '  Test', fontsize=12)

plt.show()
plt.close()

# %%
# Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
train_size = int(0.7 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

print('Train data size:', train_data.shape)
print('Test data size:', test_data.shape)
# Out:
# Train data size: (1640, 1)
# Test data size: (704, 1)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# Reshape lại dữ liệu vì đây là yêu cầu cần thiết đối với đầu vào của LSTM
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

print('Train data size shape:', X_train.shape)
print('Test data size shape:', X_test.shape)
# Out:
# Train data size shape: (1539, 100, 1)
# Test data size shape: (603, 100, 1)

# %% [markdown]
# #### Tạo mô hình và train

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100, 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step - loss: 0.0677 - val_loss: 0.0028
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.0033 - val_loss: 0.0041
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.0010 - val_loss: 0.0027
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 7.0583e-04 - val_loss: 0.0029
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 8.2761e-04 - val_loss: 0.0031
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 7.5166e-04 - val_loss: 0.0028
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 7.3533e-04 - val_loss: 0.0020
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - loss: 7.5169e-04 - val_loss: 0.0024
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 6.9313e-04 - val_loss: 0.0027
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 7.4195e-04 - val_loss: 0.0017
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 7.1553e-04 - val_loss: 0.0017
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 9.1368e-04 - val_loss: 0.0021
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 7.0157e-04 - val_loss: 0.0017
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 9.3303e-04 - val_loss: 0.0020
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - loss: 5.9613e-04 - val_loss: 0.0026
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 6.2562e-04 - val_loss: 0.0026
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 6.2828e-04 - val_loss: 0.0016
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 133ms/step - loss: 6.2970e-04 - val_loss: 0.0020
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 4.9678e-04 - val_loss: 0.0025
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - loss: 5.0743e-04 - val_loss: 0.0024
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 4.6994e-04 - val_loss: 0.0011
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 7.4254e-04 - val_loss: 0.0013
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 4.6948e-04 - val_loss: 0.0027
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 5.3520e-04 - val_loss: 0.0023
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 5.8122e-04 - val_loss: 0.0014
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 4.7331e-04 - val_loss: 0.0012
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 5.2076e-04 - val_loss: 9.7044e-04
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 6.7498e-04 - val_loss: 8.3934e-04
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 134ms/step - loss: 5.5603e-04 - val_loss: 9.3198e-04
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - loss: 4.7568e-04 - val_loss: 0.0027
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 5.3711e-04 - val_loss: 0.0033
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 5.2585e-04 - val_loss: 0.0015
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 4.3631e-04 - val_loss: 0.0011
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 4.7451e-04 - val_loss: 8.2948e-04
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 6.8458e-04 - val_loss: 8.0989e-04
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 5.0949e-04 - val_loss: 0.0012
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 3.9818e-04 - val_loss: 7.0064e-04
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 133ms/step - loss: 4.1467e-04 - val_loss: 6.1594e-04
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 4.7535e-04 - val_loss: 6.7373e-04
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - loss: 4.1858e-04 - val_loss: 8.0558e-04
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 5.5688e-04 - val_loss: 6.3519e-04
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 3.8771e-04 - val_loss: 0.0011
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 3.7537e-04 - val_loss: 7.2810e-04
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - loss: 3.6158e-04 - val_loss: 8.8054e-04
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 3.9086e-04 - val_loss: 6.2216e-04
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - loss: 3.6312e-04 - val_loss: 6.0590e-04
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 3.6978e-04 - val_loss: 6.3687e-04
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 3.3908e-04 - val_loss: 5.3297e-04
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 3.6681e-04 - val_loss: 5.4336e-04
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 4.2015e-04 - val_loss: 0.0010
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 3.0660e-04 - val_loss: 8.2336e-04
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - loss: 3.0465e-04 - val_loss: 6.0697e-04
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 3.2605e-04 - val_loss: 7.8202e-04
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 133ms/step - loss: 3.1179e-04 - val_loss: 0.0012
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 3.0060e-04 - val_loss: 4.9487e-04
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 2.6337e-04 - val_loss: 0.0030
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 6.1937e-04 - val_loss: 7.2474e-04
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 3.0910e-04 - val_loss: 4.3445e-04
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 3.2906e-04 - val_loss: 6.5678e-04
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 139ms/step - loss: 2.5762e-04 - val_loss: 7.2645e-04
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 2.6621e-04 - val_loss: 3.9161e-04
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 2.9858e-04 - val_loss: 0.0010
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 3.2163e-04 - val_loss: 4.2747e-04
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 2.4696e-04 - val_loss: 4.6604e-04
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 2.2080e-04 - val_loss: 3.2389e-04
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 2.4176e-04 - val_loss: 0.0027
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 134ms/step - loss: 5.5335e-04 - val_loss: 5.4131e-04
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 2.1981e-04 - val_loss: 0.0017
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 3.0267e-04 - val_loss: 3.5145e-04
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 2.0337e-04 - val_loss: 6.1749e-04
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 1.9232e-04 - val_loss: 4.9327e-04
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 2.3387e-04 - val_loss: 2.8156e-04
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 2.0551e-04 - val_loss: 2.9266e-04
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 1.9062e-04 - val_loss: 2.8133e-04
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 2.0779e-04 - val_loss: 7.5546e-04
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 133ms/step - loss: 2.3425e-04 - val_loss: 5.6977e-04
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 1.8087e-04 - val_loss: 2.5442e-04
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - loss: 2.1977e-04 - val_loss: 3.7860e-04
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 1.8439e-04 - val_loss: 2.7897e-04
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 1.7894e-04 - val_loss: 2.1946e-04
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 1.7332e-04 - val_loss: 2.2181e-04
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 1.9381e-04 - val_loss: 2.5060e-04
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 1.8305e-04 - val_loss: 2.2952e-04
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 1.6787e-04 - val_loss: 6.1790e-04
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 2.4830e-04 - val_loss: 2.2653e-04
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 1.6624e-04 - val_loss: 2.2973e-04
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 1.5739e-04 - val_loss: 2.1506e-04
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - loss: 1.4948e-04 - val_loss: 9.5158e-04
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 2.8178e-04 - val_loss: 9.4623e-04
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 2.2377e-04 - val_loss: 2.6476e-04
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 133ms/step - loss: 2.0769e-04 - val_loss: 2.3441e-04
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 1.9196e-04 - val_loss: 5.8493e-04
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 133ms/step - loss: 2.5577e-04 - val_loss: 3.9489e-04
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 1.6447e-04 - val_loss: 3.4485e-04
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 1.7941e-04 - val_loss: 6.1110e-04
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 1.7085e-04 - val_loss: 2.3739e-04
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 1.8006e-04 - val_loss: 5.1897e-04
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 1.6614e-04 - val_loss: 6.2103e-04
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 1.8642e-04 - val_loss: 1.9194e-04
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 1.5996e-04 - val_loss: 2.2559e-04

# %% [markdown]
# #### Dự báo và trực quan hoá

# %%
y_pred = model.predict(X_test)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step

# %%
# Chuẩn hóa dữ liệu y_pred, y_test
y_pred = scaler.inverse_transform(y_pred)
ytest = scaler.inverse_transform(ytest.reshape(-1, 1))

# %%
# Đánh giá độ chính xác thuật toán bằng RMSE
test_rmse = np.sqrt(np.mean((y_pred - ytest)**2))
test_mape = np.mean(np.abs((ytest - y_pred) / ytest)) * 100
test_mae = np.mean(np.abs(ytest - y_pred))


print('Testing RMSE:', test_rmse)
print('Testing MAPE:', test_mape)
print('Testing MAE:', test_mae)
# Out:
# Testing RMSE: 18.856532865663947
# Testing MAPE: 0.7635776438813766
# Testing MAE: 14.96291263418234

# %%
# 13. Dự báo 90 ngày tiếp theo
x_input=test_data[:100].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()


lst_output=[]
n_steps=100
i=0

while(i<90):

    if(len(temp_input)>100):
        x_input=np.array(temp_input[1:])
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i=i+1

# %%
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data), color='green')
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index,scaler.inverse_transform(test_data), color='red')

test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index,(y_pred), color='blue')

predict_data_index_30 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
plt.plot(predict_data_index_30,scaler.inverse_transform(lst_output[0:30]), color='darkred')
predict_data_index_60 = pd.RangeIndex(start=len(df1)+29, stop=len(df1)+59, step=1)
plt.plot(predict_data_index_60,scaler.inverse_transform(lst_output[30:60]), color='orange')
predict_data_index_90 = pd.RangeIndex(start=len(df1)+59, stop=len(df1)+89, step=1)
plt.plot(predict_data_index_90,scaler.inverse_transform(lst_output[60:90]), color='purple')

plt.legend(['Dữ liệu huấn luyện','Dữ liệu thực tế','Dữ liệu dự đoán','Dự đoán 30 ngày', 'Dự đoán 60 ngày', 'Dự đoán 90 ngày'])
plt.title('Dự đoán giá vàng tỉ lệ 7:3(LSTM)')
plt.ylabel('Giá vàng')
plt.show()

# %% [markdown]
# ### b.Dữ liệu giá bạc

# %% [markdown]
# #### Đọc dữ liệu và chia tập dữ liệu

# %%
df_silver.columns = ['Date', 'Price']
df_silver['Date'] = pd.to_datetime(df_silver['Date'])
df_silver['Price'] = df_silver.Price.astype(float)

df1 = df_silver.reset_index()['Price']

df1
# Out:
# 0       16.993771
# 1       17.196475
# 2       17.112426
# 3       17.200338
# 4       17.220985
#           ...
# 2339    31.790544
# 2340    31.992130
# 2341    31.825860
# 2342    31.137894
# 2343    30.408189
# Name: Price, Length: 2344, dtype: float64

# %%
x_plot = df_silver.Date
y_plot = df1.values
x_test_position = int(len(df_silver)*0.7)
x_value = df_silver.Date.iloc[x_test_position]
fig = plt.figure(figsize=(10, 5))

fig.tight_layout()

plt.plot(x_plot, y_plot)
plt.title('Biểu đồ đường thể hiện giá bạc')
plt.xlabel('Ngày', fontsize=17)
plt.ylabel('Giá bạc', fontsize=17)

plt.axvline(x_value, color='black', linestyle='-.')
plt.text(x_value, y_plot[x_test_position] - 10, '  Test', fontsize=12)

plt.show()
plt.close()

# %%
# Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
train_size = int(0.7 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

print('Train data size:', train_data.shape)
print('Test data size:', test_data.shape)
# Out:
# Train data size: (1640, 1)
# Test data size: (704, 1)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# Reshape lại dữ liệu vì đây là yêu cầu cần thiết đối với đầu vào của LSTM
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

print('Train data size shape:', X_train.shape)
print('Test data size shape:', X_test.shape)
# Out:
# Train data size shape: (1539, 100, 1)
# Test data size shape: (603, 100, 1)

# %% [markdown]
# #### Tạo mô hình và train

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100, 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 181ms/step - loss: 0.0998 - val_loss: 0.0063
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.0066 - val_loss: 0.0038
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0019 - val_loss: 0.0034
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0015 - val_loss: 0.0029
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0010 - val_loss: 0.0020
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 8.2749e-04 - val_loss: 0.0013
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0010 - val_loss: 0.0022
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.0012 - val_loss: 9.8339e-04
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 8.8193e-04 - val_loss: 0.0012
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 7.9944e-04 - val_loss: 0.0021
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 9.9359e-04 - val_loss: 8.8332e-04
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - loss: 7.8353e-04 - val_loss: 0.0021
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 8.0014e-04 - val_loss: 8.7344e-04
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 7.6604e-04 - val_loss: 9.5536e-04
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 6.8529e-04 - val_loss: 0.0013
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.0012 - val_loss: 9.7957e-04
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 6.5163e-04 - val_loss: 8.4501e-04
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 7.6781e-04 - val_loss: 8.1673e-04
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - loss: 6.3489e-04 - val_loss: 7.9433e-04
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 7.5781e-04 - val_loss: 7.6596e-04
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 6.3083e-04 - val_loss: 0.0027
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.0012 - val_loss: 8.6635e-04
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 6.5163e-04 - val_loss: 0.0017
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0011 - val_loss: 6.9071e-04
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 8.0950e-04 - val_loss: 7.5772e-04
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - loss: 6.9903e-04 - val_loss: 7.4734e-04
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - loss: 6.3388e-04 - val_loss: 8.7667e-04
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 7.5189e-04 - val_loss: 6.6421e-04
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 5.3990e-04 - val_loss: 5.9575e-04
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 4.9385e-04 - val_loss: 5.9671e-04
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 6.0151e-04 - val_loss: 6.8214e-04
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 5.4142e-04 - val_loss: 7.2977e-04
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 5.8124e-04 - val_loss: 5.3725e-04
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 4.6021e-04 - val_loss: 6.4265e-04
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 5.1912e-04 - val_loss: 6.3187e-04
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 5.2376e-04 - val_loss: 6.1318e-04
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 4.7200e-04 - val_loss: 5.3208e-04
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 4.7071e-04 - val_loss: 7.3102e-04
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 5.4492e-04 - val_loss: 0.0010
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 6.8202e-04 - val_loss: 6.3506e-04
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 3.9023e-04 - val_loss: 4.8834e-04
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 3.8792e-04 - val_loss: 4.7371e-04
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 4.8136e-04 - val_loss: 5.0950e-04
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 4.1398e-04 - val_loss: 9.1911e-04
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 5.5314e-04 - val_loss: 4.5390e-04
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 4.3219e-04 - val_loss: 4.4996e-04
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - loss: 3.8396e-04 - val_loss: 4.4423e-04
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 3.6202e-04 - val_loss: 4.8677e-04
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 3.9167e-04 - val_loss: 4.6674e-04
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 4.2063e-04 - val_loss: 4.4308e-04
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 3.5700e-04 - val_loss: 0.0022
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 9.0103e-04 - val_loss: 4.3193e-04
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 3.9438e-04 - val_loss: 4.2391e-04
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 3.2588e-04 - val_loss: 4.2162e-04
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 138ms/step - loss: 4.1622e-04 - val_loss: 4.2588e-04
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 3.8842e-04 - val_loss: 6.8463e-04
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 4.4444e-04 - val_loss: 4.2704e-04
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 3.3799e-04 - val_loss: 3.9989e-04
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 4.3233e-04 - val_loss: 4.3932e-04
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 4.0372e-04 - val_loss: 3.9573e-04
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 5.0435e-04 - val_loss: 0.0014
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 8.5818e-04 - val_loss: 6.7403e-04
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 4.3146e-04 - val_loss: 4.5693e-04
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 3.9255e-04 - val_loss: 4.3871e-04
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - loss: 3.6567e-04 - val_loss: 3.9270e-04
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 3.4635e-04 - val_loss: 5.1915e-04
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 3.8434e-04 - val_loss: 5.2703e-04
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 4.2481e-04 - val_loss: 3.9486e-04
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 4.2390e-04 - val_loss: 4.1732e-04
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 3.4933e-04 - val_loss: 5.7293e-04
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 4.2056e-04 - val_loss: 4.2480e-04
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 3.7212e-04 - val_loss: 6.3554e-04
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 5.2361e-04 - val_loss: 7.3585e-04

# %% [markdown]
# #### Dự báo và trực quan hoá

# %%
y_pred = model.predict(X_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step

# %%
# Chuẩn hóa dữ liệu y_pred, y_test
y_pred = scaler.inverse_transform(y_pred)
ytest = scaler.inverse_transform(ytest.reshape(-1, 1))

# %%
# Đánh giá độ chính xác thuật toán bằng RMSE
test_rmse = np.sqrt(np.mean((y_pred - ytest)**2))
test_mape = np.mean(np.abs((ytest - y_pred) / ytest)) * 100
test_mae = np.mean(np.abs(ytest - y_pred))


print('Testing RMSE:', test_rmse)
print('Testing MAPE:', test_mape)
print('Testing MAE:', test_mae)
# Out:
# Testing RMSE: 0.4016884127465475
# Testing MAPE: 1.060076223645112
# Testing MAE: 0.26523260374036606

# %%
# 13. Dự báo 90 ngày tiếp theo
x_input=test_data[:100].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()


lst_output=[]
n_steps=100
i=0

while(i<90):

    if(len(temp_input)>100):
        x_input=np.array(temp_input[1:])
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i=i+1

# %%
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data), color='green')
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index,scaler.inverse_transform(test_data), color='red')

test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index,(y_pred), color='blue')

predict_data_index_30 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
plt.plot(predict_data_index_30,scaler.inverse_transform(lst_output[0:30]), color='darkred')
predict_data_index_60 = pd.RangeIndex(start=len(df1)+29, stop=len(df1)+59, step=1)
plt.plot(predict_data_index_60,scaler.inverse_transform(lst_output[30:60]), color='orange')
predict_data_index_90 = pd.RangeIndex(start=len(df1)+59, stop=len(df1)+89, step=1)
plt.plot(predict_data_index_90,scaler.inverse_transform(lst_output[60:90]), color='purple')

plt.legend(['Dữ liệu huấn luyện','Dữ liệu thực tế','Dữ liệu dự đoán','Dự đoán 30 ngày', 'Dự đoán 60 ngày', 'Dự đoán 90 ngày'])
plt.title('Dự đoán giá bạc tỉ lệ 7:3(LSTM)')
plt.ylabel('Giá bạc')
plt.show()

# %% [markdown]
# ### c.Dữ liệu giá bạch kim

# %% [markdown]
# #### Đọc dữ liệu và chia tập dữ liệu

# %%
df_platium.columns = ['Date', 'Price']
df_platium['Date'] = pd.to_datetime(df_platium['Date'])
df_platium['Price'] = df_platium.Price.astype(float)

df1 = df_platium.reset_index()['Price']

df1
# Out:
# 0        930.030587
# 1        944.375754
# 2        954.910273
# 3        960.864535
# 4        969.196081
#            ...
# 2339    1062.333141
# 2340    1063.887962
# 2341    1036.777827
# 2342    1027.966127
# 2343    1009.071350
# Name: Price, Length: 2344, dtype: float64

# %%
x_plot = df_platium.Date
y_plot = df1.values
x_test_position = int(len(df_platium)*0.7)
x_value = df_platium.Date.iloc[x_test_position]
fig = plt.figure(figsize=(10, 5))

fig.tight_layout()

plt.plot(x_plot, y_plot)
plt.title('Biểu đồ đường thể hiện giá bạch kim')
plt.xlabel('Ngày', fontsize=17)
plt.ylabel('Giá bạch kim', fontsize=17)

plt.axvline(x_value, color='black', linestyle='-.')
plt.text(x_value, y_plot[x_test_position] - 10, '  Test', fontsize=12)

plt.show()
plt.close()

# %%
# Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
train_size = int(0.7 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

print('Train data size:', train_data.shape)
print('Test data size:', test_data.shape)
# Out:
# Train data size: (1875, 1)
# Test data size: (469, 1)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# Reshape lại dữ liệu vì đây là yêu cầu cần thiết đối với đầu vào của LSTM
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

print('Train data size shape:', X_train.shape)
print('Test data size shape:', X_test.shape)
# Out:
# Train data size shape: (1774, 100, 1)
# Test data size shape: (368, 100, 1)

# %% [markdown]
# #### Tạo mô hình và train

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100, 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 141ms/step - loss: 0.1226 - val_loss: 0.0081
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0064 - val_loss: 0.0022
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - loss: 0.0031 - val_loss: 0.0024
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 0.0027 - val_loss: 0.0021
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 131ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0013 - val_loss: 9.5766e-04
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 0.0012 - val_loss: 9.1627e-04
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0013 - val_loss: 8.9068e-04
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 0.0012 - val_loss: 8.2671e-04
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0011 - val_loss: 8.1886e-04
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 0.0010 - val_loss: 7.5735e-04
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - loss: 9.2397e-04 - val_loss: 8.3988e-04
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 9.4865e-04 - val_loss: 7.0382e-04
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 9.8230e-04 - val_loss: 6.9499e-04
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 9.6603e-04 - val_loss: 6.9275e-04
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - loss: 8.0347e-04 - val_loss: 7.2234e-04
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 7.9958e-04 - val_loss: 6.6149e-04
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 9.0230e-04 - val_loss: 6.5735e-04
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 9.6160e-04 - val_loss: 6.8196e-04
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - loss: 7.8074e-04 - val_loss: 7.8280e-04
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 8.1814e-04 - val_loss: 6.1443e-04
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 7.6709e-04 - val_loss: 8.8430e-04
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 9.0373e-04 - val_loss: 6.4168e-04
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 6.8270e-04 - val_loss: 6.7044e-04
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 7.3302e-04 - val_loss: 6.0139e-04
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 7.1533e-04 - val_loss: 8.9459e-04
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 8.0017e-04 - val_loss: 6.5353e-04
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 8.0057e-04 - val_loss: 6.2299e-04
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 7.1257e-04 - val_loss: 8.6846e-04
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 7.2587e-04 - val_loss: 5.8308e-04
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 6.1919e-04 - val_loss: 5.8113e-04
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 6.1050e-04 - val_loss: 5.5419e-04
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 6.4304e-04 - val_loss: 5.9610e-04
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 6.1129e-04 - val_loss: 5.3365e-04
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 5.8604e-04 - val_loss: 6.1861e-04
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 6.3193e-04 - val_loss: 7.6103e-04
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step - loss: 7.5068e-04 - val_loss: 6.0741e-04
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 6.2819e-04 - val_loss: 5.3428e-04
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 5.2947e-04 - val_loss: 5.1585e-04
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 5.6686e-04 - val_loss: 5.1439e-04
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 6.0919e-04 - val_loss: 7.7639e-04
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 6.3646e-04 - val_loss: 5.9962e-04
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 5.7486e-04 - val_loss: 5.7443e-04
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 5.8900e-04 - val_loss: 5.3593e-04
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 5.6876e-04 - val_loss: 4.6400e-04
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 5.9750e-04 - val_loss: 5.2604e-04
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - loss: 6.1599e-04 - val_loss: 4.7503e-04
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 4.8057e-04 - val_loss: 4.6697e-04
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 4.9848e-04 - val_loss: 5.2869e-04
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 5.1351e-04 - val_loss: 4.8054e-04
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 5.4587e-04 - val_loss: 7.4061e-04
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 6.4773e-04 - val_loss: 4.5950e-04
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 5.3636e-04 - val_loss: 4.8763e-04
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 5.0718e-04 - val_loss: 5.6875e-04
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - loss: 4.9643e-04 - val_loss: 5.6755e-04
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 4.8600e-04 - val_loss: 4.4102e-04
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 4.1375e-04 - val_loss: 4.7120e-04
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 4.9005e-04 - val_loss: 4.1505e-04
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 4.6691e-04 - val_loss: 4.7147e-04
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 5.1379e-04 - val_loss: 4.4769e-04
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 4.4224e-04 - val_loss: 4.2762e-04
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 4.8757e-04 - val_loss: 6.6688e-04
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - loss: 5.4683e-04 - val_loss: 4.1759e-04
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 4.5392e-04 - val_loss: 6.3909e-04
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 5.1452e-04 - val_loss: 5.3475e-04
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 5.9831e-04 - val_loss: 4.2064e-04
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 5.2607e-04 - val_loss: 4.2542e-04
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 4.5354e-04 - val_loss: 4.7634e-04
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 5.7223e-04 - val_loss: 4.8077e-04
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 4.6969e-04 - val_loss: 4.2856e-04
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 4.4342e-04 - val_loss: 4.0405e-04
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - loss: 5.1155e-04 - val_loss: 4.7188e-04
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 4.6405e-04 - val_loss: 4.3700e-04
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 4.8520e-04 - val_loss: 4.3675e-04
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 4.2938e-04 - val_loss: 5.2112e-04
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 4.6155e-04 - val_loss: 5.8495e-04
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 4.9460e-04 - val_loss: 4.5990e-04
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 5.3514e-04 - val_loss: 4.3526e-04
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 4.9121e-04 - val_loss: 4.0603e-04
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 4.0226e-04 - val_loss: 4.2499e-04
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 4.7597e-04 - val_loss: 4.9371e-04
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 4.8702e-04 - val_loss: 4.0812e-04

# %% [markdown]
# #### Dự báo và trực quan hoá

# %%
y_pred = model.predict(X_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step

# %%
# Chuẩn hóa dữ liệu y_pred, y_test
y_pred = scaler.inverse_transform(y_pred)
ytest = scaler.inverse_transform(ytest.reshape(-1, 1))

# %%
# Đánh giá độ chính xác thuật toán bằng RMSE
test_rmse = np.sqrt(np.mean((y_pred - ytest)**2))
test_mape = np.mean(np.abs((ytest - y_pred) / ytest)) * 100
test_mae = np.mean(np.abs(ytest - y_pred))


print('Testing RMSE:', test_rmse)
print('Testing MAPE:', test_mape)
print('Testing MAE:', test_mae)
# Out:
# Testing RMSE: 14.448898238958819
# Testing MAPE: 1.1203889677477286
# Testing MAE: 10.545258815244193

# %%
# 13. Dự báo 90 ngày tiếp theo
x_input=test_data[:100].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()


lst_output=[]
n_steps=100
i=0

while(i<90):

    if(len(temp_input)>100):
        x_input=np.array(temp_input[1:])
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i=i+1

# %%
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data), color='green')
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index,scaler.inverse_transform(test_data), color='red')

test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index,(y_pred), color='blue')

predict_data_index_30 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
plt.plot(predict_data_index_30,scaler.inverse_transform(lst_output[0:30]), color='darkred')
predict_data_index_60 = pd.RangeIndex(start=len(df1)+29, stop=len(df1)+59, step=1)
plt.plot(predict_data_index_60,scaler.inverse_transform(lst_output[30:60]), color='orange')
predict_data_index_90 = pd.RangeIndex(start=len(df1)+59, stop=len(df1)+89, step=1)
plt.plot(predict_data_index_90,scaler.inverse_transform(lst_output[60:90]), color='purple')

plt.legend(['Dữ liệu huấn luyện','Dữ liệu thực tế','Dữ liệu dự đoán','Dự đoán 30 ngày', 'Dự đoán 60 ngày', 'Dự đoán 90 ngày'])
plt.title('Dự đoán giá bạch kim tỉ lệ 7:3(LSTM)')
plt.ylabel('Giá bạch kim')
plt.show()
